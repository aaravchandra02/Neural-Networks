# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
"""
We will create the simplest possible neural network. 
It has 1 layer, and that layer has 1 neuron, and the input shape to it is just 1 value.
"""
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
"""
Sigmoid function is used as the optimizer and loss is calculated using "Mean squared error" method.
"""
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
"""
Training the neural network, where it 'learns' the relationship between the Xs 
and Ys is in the model.fit call
"""
model.fit(xs, ys, epochs=500)
# Out:
# 1.1920e-04
# Epoch 272/500
# 6/6 [==============================] - 0s 990us/sample - loss: 1.1675e-04
# Epoch 273/500
# 6/6 [==============================] - 0s 838us/sample - loss: 1.1435e-04
# Epoch 274/500
# 6/6 [==============================] - 0s 2ms/sample - loss: 1.1200e-04
# Epoch 275/500
# 6/6 [==============================] - 0s 1ms/sample - loss: 1.0970e-04
# Epoch 276/500
# 6/6 [==============================] - 0s 826us/sample - loss: 1.0745e-04
# Epoch 277/500
# 6/6 [==============================] - 0s 787us/sample - loss: 1.0524e-04
# Epoch 278/500
# 6/6 [==============================] - 0s 1ms/sample - loss: 1.0308e-04
# Epoch 279/500
# 6/6 [==============================] - 0s 650us/sample - loss: 1.0096e-04
# Epoch 280/500
# 6/6 [==============================] - 0s 640us/sample - loss: 9.8888e-05
# Epoch 281/500
# 6/6 [==============================] - 0s 2ms/sample - loss: 9.6857e-05
# Epoch 282/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[31.002958]]
